# %% [markdown]
# <a href="https://colab.research.google.com/github/maitreyee-hue/1/blob/main/Copy_of_google_translation_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install googletrans==3.1.0a0
# Out:
# ...
#      |████████████████████████████████| 61kB 3.2MB/s
# ...
#      |████████████████████████████████| 1.0MB 7.3MB/s
# ...
#      |████████████████████████████████| 51kB 5.1MB/s
# ...
#      |████████████████████████████████| 71kB 6.1MB/s
# ...
#      |████████████████████████████████| 61kB 4.8MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-cp37-none-any.whl size=16368 sha256=7e9b8723721a585b99c0dc603a250c7d247b13e3066dd49c75eaaa4f00e3ae7e
#   Stored in directory: /root/.cache/pip/wheels/27/7a/a0/aff3babbb775549ce6813cb8fa7ff3c0848c4dc62c20f8fdac
# Successfully built googletrans
# ...

# %%
from googletrans import Translator

# %%
import pandas as pd

# %%
df = pd.read_csv('marathi_tweets.csv')

# %%
df.values.tolist()[0]
# Out:
# ['प्र.१) बरं उद्या येणार का लस?\nउ.४) एकदा सांगितल ना लस नाही म्हणून.😂\n#corona #लसीकरण https://t.co/RcAnkH4BgO']

# %%
translator = Translator()
translatedlist = [translator.translate(tweet[0], dest="en").text for tweet in df.values.tolist()]

# %%
print(translatedlist)
# Out:
# ['Q1) Will the vaccine come tomorrow?\nA. 4) Once told, there is no vaccine\n#corona # vaccination https://t.co/RcAnkH4BgO', '‘Whose resignation is the BJP leader going to ask for now?’ Https://t.co/oq48PIhnRd\n\n#PMModi #SanjayRaut #Shivsena', 'The situation is out of control due to huge gatherings, crowded ceremonies and slow vaccinations as soon as the first wave subsides - WHO: https://t.co/sYaxs9qJru', 'This year Maharashtra Day should be organized in the state as easily as last year, such guidelines from the administration… https://t.co/wE53gkG85h', 'Humanity in crisis ... Contractors facilitate Corona treatment\n\nWatch the video:\nhttps://t.co/Ojkw16oiNX\n\nClick the link… https://t.co/5qXyewwosL', "Big decision of central government! Serum's other Punawalas have Y-grade protection\n\n# centralgovernment… https://t.co/bGC0vNVMcq", 'There are such people in the society, so even today humanity survives ... See a positive news from the crisis of Corona… https://t.co/PZzA4KesQ5',
# ...

# %%
tweets = pd.DataFrame(translatedlist)

# %%
tweets.to_csv('translated_tweets.csv',index=False)
